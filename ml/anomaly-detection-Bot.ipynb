# %% [markdown]
# # Steps for implementation
# #### Reading CSV
# #### Data Description
# #### Data Cleaning
# #### Data Normalization
# #### Features
# #### Applying HBOS to detect outliers from the data

# %%
#Importing Necessary Modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split     # import module for train test split
from pyod.models.hbos import HBOS
from pyod.utils.data import evaluate_print

# %%
def preprosess(df):
    df=df.dropna( axis=0, how='any')
    df=df.replace(',,', np.nan, inplace=False)
    df=df.drop(columns=[' Fwd Header Length.1'], axis=1, inplace=False)

    df.replace("Infinity", 0, inplace=True)
    df['Flow Bytes/s'].replace("Infinity", 0,inplace=True)
    df[" Flow Packets/s"].replace("Infinity", 0, inplace=True)
    df[" Flow Packets/s"].replace(np.nan, 0, inplace=True)
    df['Flow Bytes/s'].replace(np.nan, 0,inplace=True)
    df["Bwd Avg Bulk Rate"].replace("Infinity", 0, inplace=True)
    df["Bwd Avg Bulk Rate"].replace(",,", 0, inplace=True)
    df["Bwd Avg Bulk Rate"].replace(np.nan, 0, inplace=True)
    df[" Bwd Avg Packets/Bulk"].replace("Infinity", 0, inplace=True)
    df[" Bwd Avg Packets/Bulk"].replace(",,", 0, inplace=True)
    df[" Bwd Avg Packets/Bulk"].replace(np.nan, 0, inplace=True)
    df[" Bwd Avg Bytes/Bulk"].replace("Infinity", 0, inplace=True)
    df[" Bwd Avg Bytes/Bulk"].replace(",,", 0, inplace=True)
    df[" Bwd Avg Bytes/Bulk"].replace(np.nan, 0, inplace=True)
    df[" Fwd Avg Bulk Rate"].replace("Infinity", 0, inplace=True)
    df[" Fwd Avg Bulk Rate"].replace(",,", 0, inplace=True)
    df[" Fwd Avg Bulk Rate"].replace(np.nan, 0, inplace=True)
    df[" Fwd Avg Packets/Bulk"].replace("Infinity", 0, inplace=True)
    df[" Fwd Avg Packets/Bulk"].replace(",,", 0, inplace=True)
    df[" Fwd Avg Packets/Bulk"].replace(np.nan, 0, inplace=True)
    df["Fwd Avg Bytes/Bulk"].replace("Infinity", 0, inplace=True)
    df["Fwd Avg Bytes/Bulk"].replace(",,", 0, inplace=True)
    df["Fwd Avg Bytes/Bulk"].replace(np.nan, 0, inplace=True)
    df[" CWE Flag Count"].replace("Infinity", 0, inplace=True)
    df[" CWE Flag Count"].replace(",,", 0, inplace=True)
    df[" CWE Flag Count"].replace(np.nan, 0, inplace=True)
    df[" Bwd URG Flags"].replace("Infinity", 0, inplace=True)
    df[" Bwd URG Flags"].replace(",,", 0, inplace=True)
    df[" Bwd URG Flags"].replace(np.nan, 0, inplace=True)
    df[" Bwd PSH Flags"].replace("Infinity", 0, inplace=True)
    df[" Bwd PSH Flags"].replace(",,", 0, inplace=True)
    df[" Bwd PSH Flags"].replace(np.nan, 0, inplace=True)
    df[" Fwd URG Flags"].replace("Infinity", 0, inplace=True)
    df[" Fwd URG Flags"].replace(",,", 0, inplace=True)
    df[" Fwd URG Flags"].replace(np.nan, 0, inplace=True)

    df["Flow Bytes/s"]=df["Flow Bytes/s"].astype("float64")
    df[' Flow Packets/s']=df[" Flow Packets/s"].astype("float64")
    df['Bwd Avg Bulk Rate']=df["Bwd Avg Bulk Rate"].astype("float64")
    df[' Bwd Avg Packets/Bulk']=df[" Bwd Avg Packets/Bulk"].astype("float64")
    df[' Bwd Avg Bytes/Bulk']=df[" Bwd Avg Bytes/Bulk"].astype("float64")
    df[' Fwd Avg Bulk Rate']=df[" Fwd Avg Bulk Rate"].astype("float64")
    df[' Fwd Avg Packets/Bulk']=df[" Fwd Avg Packets/Bulk"].astype("float64")
    df['Fwd Avg Bytes/Bulk']=df["Fwd Avg Bytes/Bulk"].astype("float64")
    df[' CWE Flag Count']=df[" CWE Flag Count"].astype("float64")
    df[' Bwd URG Flags']=df[" Bwd URG Flags"].astype("float64")
    df[' Bwd PSH Flags']=df[" Bwd PSH Flags"].astype("float64")
    df[' Fwd URG Flags']=df[" Fwd URG Flags"].astype("float64")
    pd.set_option('display.max_rows', df.shape[0])
    df.replace('Infinity',0.0, inplace=True)
    df.replace('NaN',0.0, inplace=True)


    # old_memory_usage = df.memory_usage().sum()
    #change the variable types for low memory usage
    #int64 to int32,,, float64 to float32
    integer = []
    f = []
    for i in df.columns[:-1]:
        if df[i].dtype == "int64": integer.append(i)
        else : f.append(i)

    df[integer] = df[integer].astype("int32")
    df[f] = df[f].astype("float32")
    # print("============================")
    # print(df.info())

    # df = df.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

    return df

# %%
from pyod.models.abod import ABOD
from pyod.models.knn import KNN
from pyod.models.loci import LOCI
from pyod.models.iforest import IsolationForest
from pyod.models.iforest import IForest
from pyod.models.hbos import HBOS
from pyod.models.xgbod import XGBOD
# from pyod.models.cblof import CBLOF
# from pyod.models.lof import LOF

# from pyod.models.auto_encoder import AutoEncoder
# from statsmodels.tsa.arima_model import ARIMA
# from pyod.models.vae import VAE

import pickle

df1 = pd.read_csv("./data/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")
# print(df1.info())
# print(df1[" Label"].unique())
print(df1[' Label'].value_counts())
df = preprosess(df1)


df[' Label'] = df[' Label'].replace(['BENIGN'], 0)
df[' Label'] = df[' Label'].replace(['DDoS'], 1)

features=[" Fwd Packet Length Max"," Flow IAT Std"," Fwd Packet Length Std" ,"Fwd IAT Total",' Flow Duration', " Fwd Packet Length Mean", " Total Length of Bwd Packets", "Total Length of Fwd Packets", " Flow IAT Mean", " Bwd Packet Length Mean",  " Flow IAT Max", " Bwd Packet Length Std", ' Total Fwd Packets', ' Total Backward Packets',' Label']

df = df[features].copy()
X = df[df.columns[0:-1]]
y = df[df.columns[-1]]

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2, random_state=10)

"""
clf_name = 'ABOD'
clf = ABOD(contamination=0.1)
clf.fit(X_train)
y_test_pred = clf.predict(X_test)
print("Total Samples : ",len(y_test_pred))
print( "Inliers : ",len(y_test_pred[y_test_pred == 0]))
print( "Outliers : ",len(y_test_pred[y_test_pred == 1]))

# df_ddos = df[df[' Label']== 1]
# X_Anomaly=df_ddos[features].copy()
# y_test_pred = clf.predict(X_Anomaly)  # outlier labels (0 or 1)

# print("Total Anomlus Samples : ",len(y_test_pred))
# print( "Inliers : ",len(y_test_pred[y_test_pred == 0]))
# print( "Outliers : ",len(y_test_pred[y_test_pred == 1]))
"""

# clf_name = 'HBOS'
# clf = HBOS(contamination=0.09)

"""
# train kNN detector
clf_name = 'KNN'
# clf = KNN()
clf = KNN(contamination=0.01)
clf.fit(X_train)

# On Training Data: [2.09653038e+03 5.04987153e+03 5.61514022e+01 ... 2.93246918e+03
#  2.03155782e+05 3.76400853e+03]
# KNN ROC:0.5838, precision @ rank n:0.6122

# On Test Data: [108262.00062067 361954.56090511   1807.18604206 ...    513.80439239
#   57850.85059078   3318.69794686]
# KNN ROC:0.5834, precision @ rank n:0.6078
"""


# clf_name = 'LOCI'
# clf = LOCI()
# clf.fit(X_train[:1000])


# clf_name = 'IForest'
# clf = IsolationForest(contamination=0.001)
# clf.fit(X_train)

# train IForest detector
# clf_name = 'IForest'
# clf = IForest()
# clf.fit(X_train)

clf_name = 'XGBOD'
clf = XGBOD(random_state=42)
clf.fit(X_train, y_train)

with open(clf_name+'.pkl', 'wb') as f:
    pickle.dump(clf, f)

# with open(clf_name+'.pkl', 'rb') as f:
#     model = pickle.load(f)  
"""
# 410m
# On Training Data:
# XGBOD ROC:1.0, precision @ rank n:0.9995

# On Test Data:
# XGBOD ROC:1.0, precision @ rank n:0.9993
"""
# y_test_pred = clf.predict(X_test)
# print("Total Samples : ",len(y_test_pred))
# print( "Inliers : ",len(y_test_pred[y_test_pred == 0]))
# print( "Outliers : ",len(y_test_pred[y_test_pred == 1]))
# y_test_pred = clf.predict(X_Anomaly)  # outlier labels (0 or 1)
# print("Total Anomlus Samples : ",len(y_test_pred))
# print( "Inliers : ",len(y_test_pred[y_test_pred == 0]))
# print( "Outliers : ",len(y_test_pred[y_test_pred == 1]))



# clf_name = 'CBLOF'
# clf = CBLOF(contamination=0.09)
# clf = CBLOF(contamination=0.1)


# clf2 = AutoEncoder(hidden_neurons =[14, 10,2, 10, 14], epochs=20)
# clf2.fit(X_train)

# clf.fit(X_train)


# clf_name = 'LOF'
# clf = LOF(contamination=0.000001)
# clf = LOF(contamination=0.1)

# clf.fit(X_train)


y_train_pred = clf.labels_  # binary labels (0: inliers, 1: outliers)
y_train_scores = clf.decision_scores_  # raw outlier scores

# get the prediction on the test data
y_test_pred = clf.predict(X_test)  # outlier labels (0 or 1)
y_test_scores = clf.decision_function(X_test)  # outlier scores

# evaluate and print the results
print("\nOn Training Data:")
evaluate_print(clf_name, y_train, y_train_scores)
print("\nOn Test Data:")
evaluate_print(clf_name, y_test, y_test_scores)


"""
# get the prediction labels and outlier scores of the training data
y_train_pred = clf.labels_  # binary labels (0: inliers, 1: outliersom,/)
y_train_scores = clf.decision_scores_  # raw outlier scores

# get the prediction on the test data
y_test_pred = clf.predict(X_test)  # outlier labels (0 or 1)
y_test_scores = clf.decision_function(X_test)  # outlier scores

# evaluate and print the results
print("\nOn Training Data:" , y_train_scores)
evaluate_print(clf_name, y_train, y_train_scores)
print("\nOn Test Data:" , y_test_scores)
evaluate_print(clf_name, y_test,y_test_scores)

#visualize(clf_name, X_train, y_train, X_test, y_test, y_train_pred,
#          y_test_pred, show_figure=True, save_figure=False)

"""

# model = ARIMA(X_train, order=(1, 1, 1))
# model_fit = model.fit(disp=False)
# # make prediction
# yhat = model_fit.predict(len(data), len(data), typ='levels')
# print(yhat)


# clf_name = 'VAE'
# clf = VAE(encoder_neurons=[14, 10, 6], decoder_neurons=[6, 10, 14], contamination=0.000001, epochs=20)
# clf.fit(X_train)
# # get the prediction on the test data
# y_test_pred = clf.predict(X_test)  # outlier labels (0 or 1)

# first_Row = X.loc[1,:].to_numpy().reshape(1,-1)
# print(type(single))

# lb,  lb_confidence = clf.predict(first_Row, return_confidence=True)
# print(lb,  lb_confidence, y[1])
# Out:
# DDoS      128027
# BENIGN     97718
# Name:  Label, dtype: int64
# /home/ebryx/.local/lib/python3.8/site-packages/pyod/models/base.py:431: UserWarning: y should not be presented in unsupervised learning.
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/ebryx/Documents/pcap_data_collections/server/anomaly-detection.ipynb Cell 4 in <cell line: 89>()
#      <a href='vscode-notebook-cell:/home/ebryx/Documents/pcap_data_collections/server/anomaly-detection.ipynb#W3sZmlsZQ%3D%3D?line=86'>87</a> clf_name = 'XGBOD'
#      <a href='vscode-notebook-cell:/home/ebryx/Documents/pcap_data_collections/server/anomaly-detection.ipynb#W3sZmlsZQ%3D%3D?line=87'>88</a> clf = XGBOD(random_state=42)
# ---> <a href='vscode-notebook-cell:/home/ebryx/Documents/pcap_data_collections/server/anomaly-detection.ipynb#W3sZmlsZQ%3D%3D?line=88'>89</a> clf.fit(X_train, y_train)
#      <a href='vscode-notebook-cell:/home/ebryx/Documents/pcap_data_collections/server/anomaly-detection.ipynb#W3sZmlsZQ%3D%3D?line=90'>91</a> with open(clf_name+'.pkl', 'wb') as f:
#      <a href='vscode-notebook-cell:/home/ebryx/Documents/pcap_data_collections/server/anomaly-detection.ipynb#W3sZmlsZQ%3D%3D?line=91'>92</a>     pickle.dump(clf, f)
#
# File ~/.local/lib/python3.8/site-packages/pyod/models/xgbod.py:318, in XGBOD.fit(self, X, y)
#     316 for ind, estimator in enumerate(self.estimator_list):
#     317     if self.standardization_flag_list[ind]:
# --> 318         estimator.fit(X_norm)
#     319         self.X_train_add_[:, ind] = estimator.decision_scores_
#     321     else:
#
# File ~/.local/lib/python3.8/site-packages/pyod/models/knn.py:210, in KNN.fit(self, X, y)
#     206     else:
#     207         self.tree_ = BallTree(X, leaf_size=self.leaf_size,
#     208                               metric=self.metric)
# --> 210 dist_arr, _ = self.neigh_.kneighbors(n_neighbors=self.n_neighbors,
#     211                                      return_distance=True)
#     212 dist = self._get_dist_by_method(dist_arr)
#     214 self.decision_scores_ = dist.ravel()
#
# File /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_base.py:879, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     873     if issparse(X):
#     874         raise ValueError(
#     875             "%s does not work with sparse matrices. Densify the data, "
#     876             "or set algorithm='brute'"
#     877             % self._fit_method
#     878         )
# --> 879     chunked_results = Parallel(n_jobs, prefer="threads")(
#     880         delayed(_tree_query_parallel_helper)(
#     881             self._tree, X[s], n_neighbors, return_distance
#     882         )
#     883         for s in gen_even_slices(X.shape[0], n_jobs)
#     884     )
#     885 else:
#     886     raise ValueError("internal: _fit_method not recognized")
#
# File /usr/local/lib/python3.8/dist-packages/sklearn/utils/parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File /usr/local/lib/python3.8/dist-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /usr/local/lib/python3.8/dist-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File /usr/local/lib/python3.8/dist-packages/sklearn/utils/parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File /usr/local/lib/python3.8/dist-packages/sklearn/neighbors/_base.py:685, in _tree_query_parallel_helper(tree, *args, **kwargs)
#     679 def _tree_query_parallel_helper(tree, *args, **kwargs):
#     680     """Helper for the Parallel calls in KNeighborsMixin.kneighbors.
#     681
#     682     The Cython method tree.query is not directly picklable by cloudpickle
#     683     under PyPy.
#     684     """
# --> 685     return tree.query(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
# ! pip install -U imbalanced-learn
# https://github.com/dataprofessor/imbalanced-data/blob/main/imbalanced_learn.ipynb
! pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.4-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      |████████████████████████████████| 193.6 MB 10 kB/s  eta 0:00:01    |█▋                              | 10.0 MB 1.2 MB/s eta 0:02:36
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in /home/ebryx/.local/lib/python3.8/site-packages (from xgboost) (1.23.1)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.4

# %%
df2=pd.read_csv("./data/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv")
print(df2[" Label"].unique())
print(df2[' Label'].value_counts())


# df2[' Label'].value_counts().plot.pie(autopct= " %.2f")

from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(sampling_strategy=1) # Numerical value
# rus = RandomUnderSampler(sampling_strategy="not minority") # String


X = df.drop([' Label'], axis=1)
y = df[' Label']

X_res, y_res = rus.fit_resample(X, y)

ax = y_res.value_counts().plot.pie(autopct='%.2f')
_ = ax.set_title("Under-sampling")

# X_res.value_counts()
print(y_res.value_counts())
# Out:
# ['BENIGN' 'PortScan']
# PortScan    158930
# BENIGN      127537
# Name:  Label, dtype: int64
# 0    97714
# 1    97714
# Name:  Label, dtype: int64

# %%
#Importing Necessary Modules
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split     # import module for train test split
from pyod.models.hbos import HBOS
from pyod.utils.data import evaluate_print
from pyod.models.xgbod import XGBOD


df3=pd.read_csv("./data/Friday-WorkingHours-Morning.pcap_ISCX.csv")
# print(df3[" Label"].unique())
print(df3[' Label'].value_counts())

df3[' Label'] = df3[' Label'].replace(['BENIGN'], 0)
df3[' Label'] = df3[' Label'].replace(['Bot'], 1)

df = preprosess(df3)
print(df.info())

X = df.drop([' Label'], axis=1)
y = df[' Label']

X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2, random_state=10)

X_train = X_train.replace((np.inf, -np.inf, np.nan), 0).reset_index(drop=True)

# from imblearn.under_sampling import RandomUnderSampler
# rus = RandomUnderSampler(sampling_strategy=1) # Numerical value
# # rus = RandomUnderSampler(sampling_strategy="not minority") # String
# X_res, y_res = rus.fit_resample(X, y)

# ax = y_res.value_counts().plot.pie(autopct='%.2f')
# _ = ax.set_title("Under-sampling")

# # X_res.value_counts()
# print(y_res.value_counts())

# X_train, X_test, y_train, y_test=train_test_split(X_res,y_res,test_size=0.2, random_state=10)

clf_name = 'XGBOD'
clf = XGBOD(random_state=42)
clf.fit(X_train, y_train)

with open(clf_name+"_bot"+'.pkl', 'wb') as f:
    pickle.dump(clf, f)

y_train_pred = clf.labels_  # binary labels (0: inliers, 1: outliers)
y_train_scores = clf.decision_scores_  # raw outlier scores

# get the prediction on the test data
y_test_pred = clf.predict(X_test)  # outlier labels (0 or 1)
y_test_scores = clf.decision_function(X_test)  # outlier scores

# evaluate and print the results
print("\nOn Training Data:")
evaluate_print(clf_name, y_train, y_train_scores)
print("\nOn Test Data:")
evaluate_print(clf_name, y_test, y_test_scores)
# Out:
# BENIGN    189067
# Bot         1966
# Name:  Label, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 191005 entries, 0 to 191032
# Data columns (total 78 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             191005 non-null  int32
#  1    Flow Duration                191005 non-null  int32
#  2    Total Fwd Packets            191005 non-null  int32
#  3    Total Backward Packets       191005 non-null  int32
#  4   Total Length of Fwd Packets   191005 non-null  int32
#  5    Total Length of Bwd Packets  191005 non-null  int32
#  6    Fwd Packet Length Max        191005 non-null  int32
#  7    Fwd Packet Length Min        191005 non-null  int32
#  8    Fwd Packet Length Mean       191005 non-null  float32
#  9    Fwd Packet Length Std        191005 non-null  float32
#  10  Bwd Packet Length Max         191005 non-null  int32
#  11   Bwd Packet Length Min        191005 non-null  int32
#  12   Bwd Packet Length Mean       191005 non-null  float32
#  13   Bwd Packet Length Std        191005 non-null  float32
#  14  Flow Bytes/s                  191005 non-null  float32
#  15   Flow Packets/s               191005 non-null  float32
#  16   Flow IAT Mean                191005 non-null  float32
#  17   Flow IAT Std                 191005 non-null  float32
#  18   Flow IAT Max                 191005 non-null  int32
#  19   Flow IAT Min                 191005 non-null  int32
#  20  Fwd IAT Total                 191005 non-null  int32
#  21   Fwd IAT Mean                 191005 non-null  float32
#  22   Fwd IAT Std                  191005 non-null  float32
#  23   Fwd IAT Max                  191005 non-null  int32
#  24   Fwd IAT Min                  191005 non-null  int32
#  25  Bwd IAT Total                 191005 non-null  int32
#  26   Bwd IAT Mean                 191005 non-null  float32
#  27   Bwd IAT Std                  191005 non-null  float32
#  28   Bwd IAT Max                  191005 non-null  int32
#  29   Bwd IAT Min                  191005 non-null  int32
#  30  Fwd PSH Flags                 191005 non-null  int32
#  31   Bwd PSH Flags                191005 non-null  float32
#  32   Fwd URG Flags                191005 non-null  float32
#  33   Bwd URG Flags                191005 non-null  float32
#  34   Fwd Header Length            191005 non-null  int32
#  35   Bwd Header Length            191005 non-null  int32
#  36  Fwd Packets/s                 191005 non-null  float32
#  37   Bwd Packets/s                191005 non-null  float32
#  38   Min Packet Length            191005 non-null  int32
#  39   Max Packet Length            191005 non-null  int32
#  40   Packet Length Mean           191005 non-null  float32
#  41   Packet Length Std            191005 non-null  float32
#  42   Packet Length Variance       191005 non-null  float32
#  43  FIN Flag Count                191005 non-null  int32
#  44   SYN Flag Count               191005 non-null  int32
#  45   RST Flag Count               191005 non-null  int32
#  46   PSH Flag Count               191005 non-null  int32
#  47   ACK Flag Count               191005 non-null  int32
#  48   URG Flag Count               191005 non-null  int32
#  49   CWE Flag Count               191005 non-null  float32
#  50   ECE Flag Count               191005 non-null  int32
#  51   Down/Up Ratio                191005 non-null  int32
#  52   Average Packet Size          191005 non-null  float32
#  53   Avg Fwd Segment Size         191005 non-null  float32
#  54   Avg Bwd Segment Size         191005 non-null  float32
#  55  Fwd Avg Bytes/Bulk            191005 non-null  float32
#  56   Fwd Avg Packets/Bulk         191005 non-null  float32
#  57   Fwd Avg Bulk Rate            191005 non-null  float32
#  58   Bwd Avg Bytes/Bulk           191005 non-null  float32
#  59   Bwd Avg Packets/Bulk         191005 non-null  float32
#  60  Bwd Avg Bulk Rate             191005 non-null  float32
#  61  Subflow Fwd Packets           191005 non-null  int32
#  62   Subflow Fwd Bytes            191005 non-null  int32
#  63   Subflow Bwd Packets          191005 non-null  int32
#  64   Subflow Bwd Bytes            191005 non-null  int32
#  65  Init_Win_bytes_forward        191005 non-null  int32
#  66   Init_Win_bytes_backward      191005 non-null  int32
#  67   act_data_pkt_fwd             191005 non-null  int32
#  68   min_seg_size_forward         191005 non-null  int32
#  69  Active Mean                   191005 non-null  float32
#  70   Active Std                   191005 non-null  float32
#  71   Active Max                   191005 non-null  int32
#  72   Active Min                   191005 non-null  int32
#  73  Idle Mean                     191005 non-null  float32
#  74   Idle Std                     191005 non-null  float32
#  75   Idle Max                     191005 non-null  int32
#  76   Idle Min                     191005 non-null  int32
#  77   Label                        191005 non-null  int64
# dtypes: float32(34), int32(43), int64(1)
# memory usage: 59.0 MB
# None
# /home/ebryx/.local/lib/python3.8/site-packages/pyod/models/base.py:431: UserWarning: y should not be presented in unsupervised learning.
#   warnings.warn(

# %%
# df4=pd.read_csv("./data/Monday-WorkingHours.pcap_ISCX.csv")
# print(df4[" Label"].unique())
# Out:
# ['BENIGN']

# %%
df5 = pd.read_csv("./data/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv")
print(df5[" Label"].unique())
df5[' Label'].value_counts()
# Out:
# ['BENIGN' 'Infiltration']
# BENIGN          288566
# Infiltration        36
# Name:  Label, dtype: int64

# %%
df6 = pd.read_csv("./data/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv")
df6[" Label"] = df6[" Label"].replace(["Web Attack � Brute Force","Web Attack � XSS","Web Attack � Sql Injection"],"Web Attack")
# print(df6[" Label"].unique())
df6[' Label'].value_counts()
# Out:
# BENIGN        168186
# Web Attack      2180
# Name:  Label, dtype: int64

# %%
df7 = pd.read_csv("./data//Tuesday-WorkingHours.pcap_ISCX.csv")
# print(df7[" Label"].unique())
df7[' Label'].value_counts()
# Out:
# BENIGN         432074
# FTP-Patator      7938
# SSH-Patator      5897
# Name:  Label, dtype: int64

# %%
df8=pd.read_csv("./data/Wednesday-workingHours.pcap_ISCX.csv")
# print(df8[" Label"].unique())
# # merging similar classes with low instances
df=pd.concat([df8,df1.loc[df1[' Label'] == 'DDoS']])
df[" Label"] = df[" Label"].replace(["DoS Hulk","DoS GoldenEye","DoS slowloris","DoS Slowhttptest","DDoS"],"DoS")
# remove Heartbleed attacks
df.drop(df.loc[df[' Label']== "Heartbleed"].index, inplace=True)
df[' Label'].value_counts()
# df1[" Label"].head()
# Out:
# BENIGN    440031
# DoS       380688
# Name:  Label, dtype: int64

# %% [markdown]
# Dataset source https://www.kaggle.com/datasets/cicdataset/cicids2017

# %% [markdown]
# ### Reading CSV

# %%
df1=pd.read_csv("./data/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv")
df2=pd.read_csv("./data/Friday-WorkingHours-Afternoon-PortScan.pcap_ISCX.csv")
#df3=pd.read_csv("../Datasets/MachineLearningCVE/Friday-WorkingHours-Morning.pcap_ISCX.csv")
#df4=pd.read_csv("../Datasets/MachineLearningCVE/Monday-WorkingHours.pcap_ISCX.csv")
#df5=pd.read_csv("../Da../../Datasets/MachineLearningCSV/MachineLearningCVE/tasets/MachineLearningCVE/Thursday-WorkingHours-Afternoon-Infilteration.pcap_ISCX.csv")
#df6=pd.read_csv("../Datasets/MachineLearningCVE/Thursday-WorkingHours-Morning-WebAttacks.pcap_ISCX.csv")
#df7=pd.read_csv("../Datasets/MachineLearningCVE/Tuesday-WorkingHours.pcap_ISCX.csv")
#df8=pd.read_csv("../Datasets/MachineLearningCVE/Wednesday-workingHours.pcap_ISCX.csv")

# %%
# pip show pandas == 1.5.3
# !pip show numpy == 1.23.1
# !pip show matplotlib == 3.6.3
# !pip show scikit-learn==1.2.1
# !pip show pyod==1.0.7
# Out:
# Name: pyod
# Version: 1.0.7
# Summary: A Comprehensive and Scalable Python Library for Outlier Detection (Anomaly Detection)
# Home-page: https://github.com/yzhao062/pyod
# Author: Yue Zhao
# Author-email: zhaoy@cmu.edu
# License: UNKNOWN
# Location: /home/ebryx/.local/lib/python3.8/site-packages
# Requires: numpy, matplotlib, numba, scipy, six, joblib, scikit-learn, statsmodels
# Required-by:

# %%
df=pd.concat([df1,df2])
#df=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8])

# %%
del df1,df2
#del df1,df2,df3,df4,df5,df6,df7,df8

# %%
# category A attacks
df_bot=df[df[' Label']=='Bot']
df_ddos=df[df[' Label']=='DDoS']
df_golden_eye=df[df[' Label']=='DoS GoldenEye']
df_hulk=df[df[' Label']=='DoS Hulk']
df_ssh_patator=df[df[' Label']=='SSH-Patator']
df_ftp_patator=df[df[' Label']=='FTP-Patator']
df_infiltration=df[df[' Label']=='Infiltration']

# %%
# benign data
df_benign=df[df[' Label']=='BENIGN']

# %%
df_cat_A=pd.concat([df_bot,df_ddos,df_golden_eye,df_hulk,df_ssh_patator,df_ftp_patator,df_infiltration, df_benign])
df_cat_A.groupby(' Label').first()
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
#  Label
# BENIGN              54865               3                   2
# DDoS                   80         1293792                   3
#
#          Total Backward Packets  Total Length of Fwd Packets  \
#  Label
# BENIGN                        0                           12
# DDoS                          7                           26
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
#  Label
# BENIGN                             0                       6
# DDoS                           11607                      20
#
#          Fwd Packet Length Min   Fwd Packet Length Mean  \
#  Label
# BENIGN                       6                 6.000000
# DDoS                         0                 8.666667
#
#          Fwd Packet Length Std  ...   act_data_pkt_fwd   min_seg_size_forward  \
#  Label                          ...
# BENIGN                0.000000  ...                  1                     20
# DDoS                 10.263203  ...                  2                     20
#
#         Active Mean   Active Std   Active Max   Active Min  Idle Mean  \
#  Label
# BENIGN          0.0          0.0            0            0        0.0
# DDoS            0.0          0.0            0            0        0.0
#
#          Idle Std   Idle Max   Idle Min
#  Label
# BENIGN        0.0          0          0
# DDoS          0.0          0          0
#
# [2 rows x 78 columns]

# %%
del df_bot,df_ddos,df_golden_eye,df_hulk,df_ssh_patator,df_ftp_patator,df_infiltration, df_benign

# %%
df=df_cat_A.copy()

# %%
del df_cat_A

# %%
df.groupby(' Label').first()
# Out:
#          Destination Port   Flow Duration   Total Fwd Packets  \
#  Label
# BENIGN              54865               3                   2
# DDoS                   80         1293792                   3
#
#          Total Backward Packets  Total Length of Fwd Packets  \
#  Label
# BENIGN                        0                           12
# DDoS                          7                           26
#
#          Total Length of Bwd Packets   Fwd Packet Length Max  \
#  Label
# BENIGN                             0                       6
# DDoS                           11607                      20
#
#          Fwd Packet Length Min   Fwd Packet Length Mean  \
#  Label
# BENIGN                       6                 6.000000
# DDoS                         0                 8.666667
#
#          Fwd Packet Length Std  ...   act_data_pkt_fwd   min_seg_size_forward  \
#  Label                          ...
# BENIGN                0.000000  ...                  1                     20
# DDoS                 10.263203  ...                  2                     20
#
#         Active Mean   Active Std   Active Max   Active Min  Idle Mean  \
#  Label
# BENIGN          0.0          0.0            0            0        0.0
# DDoS            0.0          0.0            0            0        0.0
#
#          Idle Std   Idle Max   Idle Min
#  Label
# BENIGN        0.0          0          0
# DDoS          0.0          0          0
#
# [2 rows x 78 columns]

# %% [markdown]
# ### Data Description

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 353282 entries, 18883 to 286466
# Data columns (total 79 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0    Destination Port             353282 non-null  int64
#  1    Flow Duration                353282 non-null  int64
#  2    Total Fwd Packets            353282 non-null  int64
#  3    Total Backward Packets       353282 non-null  int64
#  4   Total Length of Fwd Packets   353282 non-null  int64
#  5    Total Length of Bwd Packets  353282 non-null  int64
#  6    Fwd Packet Length Max        353282 non-null  int64
#  7    Fwd Packet Length Min        353282 non-null  int64
#  8    Fwd Packet Length Mean       353282 non-null  float64
#  9    Fwd Packet Length Std        353282 non-null  float64
#  10  Bwd Packet Length Max         353282 non-null  int64
#  11   Bwd Packet Length Min        353282 non-null  int64
#  12   Bwd Packet Length Mean       353282 non-null  float64
#  13   Bwd Packet Length Std        353282 non-null  float64
#  14  Flow Bytes/s                  353263 non-null  float64
#  15   Flow Packets/s               353282 non-null  float64
#  16   Flow IAT Mean                353282 non-null  float64
#  17   Flow IAT Std                 353282 non-null  float64
#  18   Flow IAT Max                 353282 non-null  int64
#  19   Flow IAT Min                 353282 non-null  int64
#  20  Fwd IAT Total                 353282 non-null  int64
#  21   Fwd IAT Mean                 353282 non-null  float64
#  22   Fwd IAT Std                  353282 non-null  float64
#  23   Fwd IAT Max                  353282 non-null  int64
#  24   Fwd IAT Min                  353282 non-null  int64
#  25  Bwd IAT Total                 353282 non-null  int64
#  26   Bwd IAT Mean                 353282 non-null  float64
#  27   Bwd IAT Std                  353282 non-null  float64
#  28   Bwd IAT Max                  353282 non-null  int64
#  29   Bwd IAT Min                  353282 non-null  int64
#  30  Fwd PSH Flags                 353282 non-null  int64
#  31   Bwd PSH Flags                353282 non-null  int64
#  32   Fwd URG Flags                353282 non-null  int64
#  33   Bwd URG Flags                353282 non-null  int64
#  34   Fwd Header Length            353282 non-null  int64
#  35   Bwd Header Length            353282 non-null  int64
#  36  Fwd Packets/s                 353282 non-null  float64
#  37   Bwd Packets/s                353282 non-null  float64
#  38   Min Packet Length            353282 non-null  int64
#  39   Max Packet Length            353282 non-null  int64
#  40   Packet Length Mean           353282 non-null  float64
#  41   Packet Length Std            353282 non-null  float64
#  42   Packet Length Variance       353282 non-null  float64
#  43  FIN Flag Count                353282 non-null  int64
#  44   SYN Flag Count               353282 non-null  int64
#  45   RST Flag Count               353282 non-null  int64
#  46   PSH Flag Count               353282 non-null  int64
#  47   ACK Flag Count               353282 non-null  int64
#  48   URG Flag Count               353282 non-null  int64
#  49   CWE Flag Count               353282 non-null  int64
#  50   ECE Flag Count               353282 non-null  int64
#  51   Down/Up Ratio                353282 non-null  int64
#  52   Average Packet Size          353282 non-null  float64
#  53   Avg Fwd Segment Size         353282 non-null  float64
#  54   Avg Bwd Segment Size         353282 non-null  float64
#  55   Fwd Header Length.1          353282 non-null  int64
#  56  Fwd Avg Bytes/Bulk            353282 non-null  int64
#  57   Fwd Avg Packets/Bulk         353282 non-null  int64
#  58   Fwd Avg Bulk Rate            353282 non-null  int64
#  59   Bwd Avg Bytes/Bulk           353282 non-null  int64
#  60   Bwd Avg Packets/Bulk         353282 non-null  int64
#  61  Bwd Avg Bulk Rate             353282 non-null  int64
#  62  Subflow Fwd Packets           353282 non-null  int64
#  63   Subflow Fwd Bytes            353282 non-null  int64
#  64   Subflow Bwd Packets          353282 non-null  int64
#  65   Subflow Bwd Bytes            353282 non-null  int64
#  66  Init_Win_bytes_forward        353282 non-null  int64
#  67   Init_Win_bytes_backward      353282 non-null  int64
#  68   act_data_pkt_fwd             353282 non-null  int64
#  69   min_seg_size_forward         353282 non-null  int64
#  70  Active Mean                   353282 non-null  float64
#  71   Active Std                   353282 non-null  float64
#  72   Active Max                   353282 non-null  int64
#  73   Active Min                   353282 non-null  int64
#  74  Idle Mean                     353282 non-null  float64
#  75   Idle Std                     353282 non-null  float64
#  76   Idle Max                     353282 non-null  int64
#  77   Idle Min                     353282 non-null  int64
#  78   Label                        353282 non-null  object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 215.6+ MB

# %%
df.describe()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# count      353282.000000    3.532820e+05       353282.000000
# mean         8317.536203    1.470301e+07            5.473658
# std         18974.050876    3.159391e+07           21.336977
# min             0.000000   -1.300000e+01            1.000000
# 25%            53.000000    2.367700e+04            2.000000
# 50%            80.000000    4.694965e+05            3.000000
# 75%           443.000000    6.696332e+06            5.000000
# max         65532.000000    1.199999e+08         3119.000000
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# count            353282.000000                353282.000000
# mean                  5.324557                   789.085334
# std                  30.756145                  3091.009774
# min                   0.000000                     0.000000
# 25%                   1.000000                    26.000000
# 50%                   2.000000                    44.000000
# 75%                   5.000000                    86.000000
# max                3635.000000                232349.000000
#
#         Total Length of Bwd Packets   Fwd Packet Length Max  \
# count                  3.532820e+05           353282.000000
# mean                   5.998437e+03              409.347516
# std                    5.552206e+04             1526.654248
# min                    0.000000e+00                0.000000
# 25%                    6.000000e+00                6.000000
# 50%                    1.500000e+02               20.000000
# 75%                    1.160100e+04               47.000000
# max                    7.150819e+06            13929.000000
#
#         Fwd Packet Length Min   Fwd Packet Length Mean  \
# count           353282.000000            353282.000000
# mean                25.766543               124.442551
# std                132.061381               412.573844
# min                  0.000000                 0.000000
# 25%                  0.000000                 6.000000
# 50%                  6.000000                 8.666667
# 75%                 31.000000                44.000000
# max               1472.000000              3867.000000
#
#         Fwd Packet Length Std  ...   act_data_pkt_fwd   min_seg_size_forward  \
# count           353282.000000  ...      353282.000000          353282.000000
# mean               157.246116  ...           3.515919              22.886063
# std                650.176230  ...          16.529588               5.380668
# min                  0.000000  ...           0.000000               0.000000
# 25%                  0.000000  ...           1.000000              20.000000
# 50%                  0.000000  ...           2.000000              20.000000
# 75%                 10.263203  ...           4.000000              20.000000
# max               6692.644993  ...        2056.000000              60.000000
#
#         Active Mean    Active Std    Active Max    Active Min     Idle Mean  \
# count  3.532820e+05  3.532820e+05  3.532820e+05  3.532820e+05  3.532820e+05
# mean   1.457166e+05  2.687304e+04  1.960644e+05  1.310762e+05  7.859771e+06
# std    7.644236e+05  2.895786e+05  9.742138e+05  7.354875e+05  1.929626e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 75%    9.920000e+02  0.000000e+00  9.920000e+02  9.910000e+02  6.105852e+06
# max    1.100000e+08  7.050000e+07  1.100000e+08  1.100000e+08  1.200000e+08
#
#            Idle Std      Idle Max      Idle Min
# count  3.532820e+05  3.532820e+05  3.532820e+05
# mean   2.357610e+06  9.528822e+06  6.165548e+06
# std    1.039089e+07  2.328394e+07  1.762792e+07
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    0.000000e+00  0.000000e+00  0.000000e+00
# 50%    0.000000e+00  0.000000e+00  0.000000e+00
# 75%    0.000000e+00  6.107426e+06  5.892240e+06
# max    7.050000e+07  1.200000e+08  1.200000e+08
#
# [8 rows x 78 columns]

# %%
df.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
#        ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count',
#        ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count',
#        ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count',
#        ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size',
#        ' Avg Fwd Segment Size', ' Avg Bwd Segment Size',
#        ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        ' Init_Win_bytes_backward', ' act_data_pkt_fwd',
#        ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max',
#        ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min',
#        ' Label'],
#       dtype='object')

# %% [markdown]
# ### Data Cleaning

# %%
#df2=df[df.columns[7:-1]]
#df2[' Label']=df[' Label']
#df=df2
#df2=[]
#del df2

# %%
df.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
#        ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count',
#        ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count',
#        ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count',
#        ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size',
#        ' Avg Fwd Segment Size', ' Avg Bwd Segment Size',
#        ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        ' Init_Win_bytes_backward', ' act_data_pkt_fwd',
#        ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max',
#        ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min',
#        ' Label'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 79

# %%
df=df.dropna( axis=0, how='any')
df=df.replace(',,', np.nan, inplace=False)
df=df.drop(columns=[' Fwd Header Length.1'], axis=1, inplace=False)

# %%
df.replace("Infinity", 0, inplace=True)
df['Flow Bytes/s'].replace("Infinity", 0,inplace=True)
df[" Flow Packets/s"].replace("Infinity", 0, inplace=True)
df[" Flow Packets/s"].replace(np.nan, 0, inplace=True)
df['Flow Bytes/s'].replace(np.nan, 0,inplace=True)


df["Bwd Avg Bulk Rate"].replace("Infinity", 0, inplace=True)
df["Bwd Avg Bulk Rate"].replace(",,", 0, inplace=True)
df["Bwd Avg Bulk Rate"].replace(np.nan, 0, inplace=True)

df[" Bwd Avg Packets/Bulk"].replace("Infinity", 0, inplace=True)
df[" Bwd Avg Packets/Bulk"].replace(",,", 0, inplace=True)
df[" Bwd Avg Packets/Bulk"].replace(np.nan, 0, inplace=True)


df[" Bwd Avg Bytes/Bulk"].replace("Infinity", 0, inplace=True)
df[" Bwd Avg Bytes/Bulk"].replace(",,", 0, inplace=True)
df[" Bwd Avg Bytes/Bulk"].replace(np.nan, 0, inplace=True)


df[" Fwd Avg Bulk Rate"].replace("Infinity", 0, inplace=True)
df[" Fwd Avg Bulk Rate"].replace(",,", 0, inplace=True)
df[" Fwd Avg Bulk Rate"].replace(np.nan, 0, inplace=True)


df[" Fwd Avg Packets/Bulk"].replace("Infinity", 0, inplace=True)
df[" Fwd Avg Packets/Bulk"].replace(",,", 0, inplace=True)
df[" Fwd Avg Packets/Bulk"].replace(np.nan, 0, inplace=True)


df["Fwd Avg Bytes/Bulk"].replace("Infinity", 0, inplace=True)
df["Fwd Avg Bytes/Bulk"].replace(",,", 0, inplace=True)
df["Fwd Avg Bytes/Bulk"].replace(np.nan, 0, inplace=True)


df[" CWE Flag Count"].replace("Infinity", 0, inplace=True)
df[" CWE Flag Count"].replace(",,", 0, inplace=True)
df[" CWE Flag Count"].replace(np.nan, 0, inplace=True)

df[" Bwd URG Flags"].replace("Infinity", 0, inplace=True)
df[" Bwd URG Flags"].replace(",,", 0, inplace=True)
df[" Bwd URG Flags"].replace(np.nan, 0, inplace=True)

df[" Bwd PSH Flags"].replace("Infinity", 0, inplace=True)
df[" Bwd PSH Flags"].replace(",,", 0, inplace=True)
df[" Bwd PSH Flags"].replace(np.nan, 0, inplace=True)

df[" Fwd URG Flags"].replace("Infinity", 0, inplace=True)
df[" Fwd URG Flags"].replace(",,", 0, inplace=True)
df[" Fwd URG Flags"].replace(np.nan, 0, inplace=True)

# %%
df["Flow Bytes/s"]=df["Flow Bytes/s"].astype("float64")
df[' Flow Packets/s']=df[" Flow Packets/s"].astype("float64")

# %%
df['Bwd Avg Bulk Rate']=df["Bwd Avg Bulk Rate"].astype("float64")
df[' Bwd Avg Packets/Bulk']=df[" Bwd Avg Packets/Bulk"].astype("float64")
df[' Bwd Avg Bytes/Bulk']=df[" Bwd Avg Bytes/Bulk"].astype("float64")
df[' Fwd Avg Bulk Rate']=df[" Fwd Avg Bulk Rate"].astype("float64")
df[' Fwd Avg Packets/Bulk']=df[" Fwd Avg Packets/Bulk"].astype("float64")
df['Fwd Avg Bytes/Bulk']=df["Fwd Avg Bytes/Bulk"].astype("float64")
df[' CWE Flag Count']=df[" CWE Flag Count"].astype("float64")
df[' Bwd URG Flags']=df[" Bwd URG Flags"].astype("float64")
df[' Bwd PSH Flags']=df[" Bwd PSH Flags"].astype("float64")
df[' Fwd URG Flags']=df[" Fwd URG Flags"].astype("float64")

# %%
pd.set_option('display.max_rows', df.shape[0])

# %%
df.replace('Infinity',0.0, inplace=True)

# %%
df.replace('NaN',0.0, inplace=True)

# %%
df.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
#        ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count',
#        ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count',
#        ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count',
#        ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size',
#        ' Avg Fwd Segment Size', ' Avg Bwd Segment Size', 'Fwd Avg Bytes/Bulk',
#        ' Fwd Avg Packets/Bulk', ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk',
#        ' Bwd Avg Packets/Bulk', 'Bwd Avg Bulk Rate', 'Subflow Fwd Packets',
#        ' Subflow Fwd Bytes', ' Subflow Bwd Packets', ' Subflow Bwd Bytes',
#        'Init_Win_bytes_forward', ' Init_Win_bytes_backward',
#        ' act_data_pkt_fwd', ' min_seg_size_forward', 'Active Mean',
#        ' Active Std', ' Active Max', ' Active Min', 'Idle Mean', ' Idle Std',
#        ' Idle Max', ' Idle Min', ' Label'],
#       dtype='object')

# %%
df_benign=df[df[' Label']=='BENIGN']
df_benign.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0              54865               3                   2
# 1              55054             109                   1
# 2              55055              52                   1
# 3              46236              34                   1
# 4              54863               3                   2
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                        0                           12
# 1                        1                            6
# 2                        1                            6
# 3                        1                            6
# 4                        0                           12
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                             0                       6
# 1                             6                       6
# 2                             6                       6
# 3                             6                       6
# 4                             0                       6
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                       6                      6.0                     0.0
# 1                       6                      6.0                     0.0
# 2                       6                      6.0                     0.0
# 3                       6                      6.0                     0.0
# 4                       6                      6.0                     0.0
#
#    ...   min_seg_size_forward  Active Mean   Active Std   Active Max  \
# 0  ...                     20          0.0          0.0            0
# 1  ...                     20          0.0          0.0            0
# 2  ...                     20          0.0          0.0            0
# 3  ...                     20          0.0          0.0            0
# 4  ...                     20          0.0          0.0            0
#
#     Active Min  Idle Mean   Idle Std   Idle Max   Idle Min   Label
# 0            0        0.0        0.0          0          0  BENIGN
# 1            0        0.0        0.0          0          0  BENIGN
# 2            0        0.0        0.0          0          0  BENIGN
# 3            0        0.0        0.0          0          0  BENIGN
# 4            0        0.0        0.0          0          0  BENIGN
#
# [5 rows x 78 columns]

# %%
df_ddos=df[df[' Label']=='DDoS']
df_ddos.head()
# Out:
#         Destination Port   Flow Duration   Total Fwd Packets  \
# 18883                 80         1293792                   3
# 18884                 80         4421382                   4
# 18885                 80         1083538                   3
# 18886                 80        80034360                   8
# 18887                 80          642654                   3
#
#         Total Backward Packets  Total Length of Fwd Packets  \
# 18883                        7                           26
# 18884                        0                           24
# 18885                        6                           26
# 18886                        4                           56
# 18887                        6                           26
#
#         Total Length of Bwd Packets   Fwd Packet Length Max  \
# 18883                         11607                      20
# 18884                             0                       6
# 18885                         11601                      20
# 18886                         11601                      20
# 18887                         11607                      20
#
#         Fwd Packet Length Min   Fwd Packet Length Mean  \
# 18883                       0                 8.666667
# 18884                       6                 6.000000
# 18885                       0                 8.666667
# 18886                       0                 7.000000
# 18887                       0                 8.666667
#
#         Fwd Packet Length Std  ...   min_seg_size_forward  Active Mean  \
# 18883               10.263203  ...                     20          0.0
# 18884                0.000000  ...                     20          0.0
# 18885               10.263203  ...                     20          0.0
# 18886                5.656854  ...                     20        939.0
# 18887               10.263203  ...                     20          0.0
#
#         Active Std   Active Max   Active Min   Idle Mean    Idle Std  \
# 18883          0.0            0            0         0.0         0.0
# 18884          0.0            0            0         0.0         0.0
# 18885          0.0            0            0         0.0         0.0
# 18886          0.0          939          939  39300000.0  44200000.0
# 18887          0.0            0            0         0.0         0.0
#
#         Idle Max   Idle Min   Label
# 18883          0          0    DDoS
# 18884          0          0    DDoS
# 18885          0          0    DDoS
# 18886   70600000    8072664    DDoS
# 18887          0          0    DDoS
#
# [5 rows x 78 columns]

# %%
X=df_benign[df_benign.columns[0:-1]]
y=df_benign[df_benign.columns[-1]]

del df

# %% [markdown]
# ### Data Normalization

# %%
from scipy import stats

# %%
cols = list(X.columns)
for col in cols:
    X[col] = stats.zscore(X[col])
    print(col)
# Out:
# /tmp/ipykernel_1582977/481651549.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X[col] = stats.zscore(X[col])
#  Destination Port
#  Flow Duration
#  Total Fwd Packets
#  Total Backward Packets
# Total Length of Fwd Packets
#  Total Length of Bwd Packets
#  Fwd Packet Length Max
#  Fwd Packet Length Min
#  Fwd Packet Length Mean
#  Fwd Packet Length Std
# Bwd Packet Length Max
#  Bwd Packet Length Min
#  Bwd Packet Length Mean
#  Bwd Packet Length Std
# Flow Bytes/s
#  Flow Packets/s
#  Flow IAT Mean
#  Flow IAT Std
# /home/ebryx/.local/lib/python3.8/site-packages/numpy/core/_methods.py:233: RuntimeWarning: invalid value encountered in subtract
#   x = asanyarray(arr - arrmean)
#  Flow IAT Max
#  Flow IAT Min
# Fwd IAT Total
#  Fwd IAT Mean
#  Fwd IAT Std
#  Fwd IAT Max
#  Fwd IAT Min
# Bwd IAT Total
#  Bwd IAT Mean
#  Bwd IAT Std
#  Bwd IAT Max
#  Bwd IAT Min
# Fwd PSH Flags
#  Bwd PSH Flags
#  Fwd URG Flags
#  Bwd URG Flags
#  Fwd Header Length
#  Bwd Header Length
# Fwd Packets/s
#  Bwd Packets/s
#  Min Packet Length
#  Max Packet Length
#  Packet Length Mean
#  Packet Length Std
#  Packet Length Variance
# FIN Flag Count
#  SYN Flag Count
#  RST Flag Count
#  PSH Flag Count
#  ACK Flag Count
#  URG Flag Count
#  CWE Flag Count
#  ECE Flag Count
#  Down/Up Ratio
#  Average Packet Size
#  Avg Fwd Segment Size
#  Avg Bwd Segment Size
# Fwd Avg Bytes/Bulk
#  Fwd Avg Packets/Bulk
#  Fwd Avg Bulk Rate
#  Bwd Avg Bytes/Bulk
#  Bwd Avg Packets/Bulk
# Bwd Avg Bulk Rate
# Subflow Fwd Packets
#  Subflow Fwd Bytes
#  Subflow Bwd Packets
#  Subflow Bwd Bytes
# Init_Win_bytes_forward
#  Init_Win_bytes_backward
#  act_data_pkt_fwd
#  min_seg_size_forward
# Active Mean
#  Active Std
#  Active Max
#  Active Min
# Idle Mean
#  Idle Std
#  Idle Max
#  Idle Min

# %%
X.head()
# Out:
#     Destination Port   Flow Duration   Total Fwd Packets  \
# 0           1.864799       -0.421474           -0.151613
# 1           1.873217       -0.421471           -0.189113
# 2           1.873261       -0.421473           -0.189113
# 3           1.480466       -0.421473           -0.189113
# 4           1.864710       -0.421474           -0.151613
#
#     Total Backward Packets  Total Length of Fwd Packets  \
# 0                -0.169201                    -0.317394
# 1                -0.143173                    -0.318971
# 2                -0.143173                    -0.318971
# 3                -0.143173                    -0.318971
# 4                -0.169201                    -0.317394
#
#     Total Length of Bwd Packets   Fwd Packet Length Max  \
# 0                     -0.075181               -0.334656
# 1                     -0.075095               -0.334656
# 2                     -0.075095               -0.334656
# 3                     -0.075095               -0.334656
# 4                     -0.075181               -0.334656
#
#     Fwd Packet Length Min   Fwd Packet Length Mean   Fwd Packet Length Std  \
# 0                -0.20243                -0.366483               -0.303627
# 1                -0.20243                -0.366483               -0.303627
# 2                -0.20243                -0.366483               -0.303627
# 3                -0.20243                -0.366483               -0.303627
# 4                -0.20243                -0.366483               -0.303627
#
#    ...   act_data_pkt_fwd   min_seg_size_forward  Active Mean   Active Std  \
# 0  ...          -0.127972              -0.734378    -0.152339    -0.116509
# 1  ...          -0.176358              -0.734378    -0.152339    -0.116509
# 2  ...          -0.176358              -0.734378    -0.152339    -0.116509
# 3  ...          -0.176358              -0.734378    -0.152339    -0.116509
# 4  ...          -0.127972              -0.734378    -0.152339    -0.116509
#
#     Active Max   Active Min  Idle Mean   Idle Std   Idle Max   Idle Min
# 0    -0.181213    -0.130066  -0.343143  -0.159248  -0.341465  -0.310434
# 1    -0.181213    -0.130066  -0.343143  -0.159248  -0.341465  -0.310434
# 2    -0.181213    -0.130066  -0.343143  -0.159248  -0.341465  -0.310434
# 3    -0.181213    -0.130066  -0.343143  -0.159248  -0.341465  -0.310434
# 4    -0.181213    -0.130066  -0.343143  -0.159248  -0.341465  -0.310434
#
# [5 rows x 77 columns]

# %% [markdown]
# ### Feature Selection

# %%
features=[" Fwd Packet Length Max"," Flow IAT Std"," Fwd Packet Length Std" ,"Fwd IAT Total",' Flow Duration', " Fwd Packet Length Mean", " Total Length of Bwd Packets", "Total Length of Fwd Packets", " Flow IAT Mean", " Bwd Packet Length Mean",  " Flow IAT Max", " Bwd Packet Length Std", ' Total Fwd Packets', ' Total Backward Packets']

# %%
X=X[features].copy()
X.head()
# Out:
#     Fwd Packet Length Max   Flow IAT Std   Fwd Packet Length Std  \
# 0               -0.334656      -0.353944               -0.303627
# 1               -0.334656      -0.353944               -0.303627
# 2               -0.334656      -0.353944               -0.303627
# 3               -0.334656      -0.353944               -0.303627
# 4               -0.334656      -0.353944               -0.303627
#
#    Fwd IAT Total   Flow Duration   Fwd Packet Length Mean  \
# 0      -0.397576       -0.421474                -0.366483
# 1      -0.397576       -0.421471                -0.366483
# 2      -0.397576       -0.421473                -0.366483
# 3      -0.397576       -0.421473                -0.366483
# 4      -0.397576       -0.421474                -0.366483
#
#     Total Length of Bwd Packets  Total Length of Fwd Packets   Flow IAT Mean  \
# 0                     -0.075181                    -0.317394       -0.316342
# 1                     -0.075095                    -0.318971       -0.316306
# 2                     -0.075095                    -0.318971       -0.316325
# 3                     -0.075095                    -0.318971       -0.316331
# 4                     -0.075181                    -0.317394       -0.316342
#
#     Bwd Packet Length Mean   Flow IAT Max   Bwd Packet Length Std  \
# 0                -0.528766      -0.364526               -0.413824
# 1                -0.506577      -0.364520               -0.413824
# 2                -0.506577      -0.364523               -0.413824
# 3                -0.506577      -0.364524               -0.413824
# 4                -0.528766      -0.364526               -0.413824
#
#     Total Fwd Packets   Total Backward Packets
# 0           -0.151613                -0.169201
# 1           -0.189113                -0.143173
# 2           -0.189113                -0.143173
# 3           -0.189113                -0.143173
# 4           -0.151613                -0.169201

# %%
len(X.columns)
# Out:
# 14

# %%
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2, random_state=10)

# %%
X_train.shape
# Out:
# (180188, 14)

# %%
X_test.shape
# Out:
# (45048, 14)

# %% [markdown]
# ### Applying Algorithms

# %%
clf_name = 'HBOS'
clf = HBOS(contamination=0.09)
clf.fit(X_train)
# Out:
# HBOS(alpha=0.1, contamination=0.09, n_bins=10, tol=0.5)

# %%
y_test_pred = clf.predict(X_test)

# %%
#y_test_arr=y_test.as_matrix()
print("Total Samples : ",len(y_test_pred))
print( "Inliers : ",len(y_test_pred[y_test_pred == 0]))
print( "Outliers : ",len(y_test_pred[y_test_pred == 1]))
# Out:
# Total Samples :  45048
# Inliers :  41042
# Outliers :  4006

# %%
X_Anomaly=df_ddos[features].copy()
len(X_Anomaly.columns)
# Out:
# 14

# %%
X_Anomaly.head()
# Out:
#         Fwd Packet Length Max   Flow IAT Std   Fwd Packet Length Std  \
# 18883                      20   4.308658e+05               10.263203
# 18884                       6   2.552043e+06                0.000000
# 18885                      20   3.777253e+05               10.263203
# 18886                      20   2.110000e+07                5.656854
# 18887                      20   2.268247e+05               10.263203
#
#        Fwd IAT Total   Flow Duration   Fwd Packet Length Mean  \
# 18883            747         1293792                 8.666667
# 18884        4421382         4421382                 6.000000
# 18885          12982         1083538                 8.666667
# 18886       78700000        80034360                 7.000000
# 18887            801          642654                 8.666667
#
#         Total Length of Bwd Packets  Total Length of Fwd Packets  \
# 18883                         11607                           26
# 18884                             0                           24
# 18885                         11601                           26
# 18886                         11601                           56
# 18887                         11607                           26
#
#         Flow IAT Mean   Bwd Packet Length Mean   Flow IAT Max  \
# 18883    1.437547e+05              1658.142857        1292730
# 18884    1.473794e+06                 0.000000        4420639
# 18885    1.354422e+05              1933.500000        1070206
# 18886    7.275851e+06              2900.250000       70600000
# 18887    8.033175e+04              1934.500000         641694
#
#         Bwd Packet Length Std   Total Fwd Packets   Total Backward Packets
# 18883             2137.297080                   3                        7
# 18884                0.000000                   4                        0
# 18885             1757.789948                   3                        6
# 18886             4128.319301                   8                        4
# 18887             2538.919278                   3                        6

# %%
y_test_pred = clf.predict(X_Anomaly)

# %%
print("Total Samples : ",len(y_test_pred))
print( "Inliers : ",len(y_test_pred[y_test_pred == 0]))
print( "Outliers : ",len(y_test_pred[y_test_pred == 1]))
# Out:
# Total Samples :  128027
# Inliers :  0
# Outliers :  128027
